# %% [markdown]
# # **3일차 팀 프로젝트: 테이블 데이터 조회 시스템 구축**
#
# ## 프로젝트 목표
# 1. 팀에서 선정한 CSV 테이블 데이터를 Supabase에 적재
# 2. SQL 쿼리로 데이터 조회 테스트
# 3. Text2SQL 시스템 구현 및 테스트
#
# ## 구현 단계
# - 환경 설정 확인
# - CSV 파일 확인 및 탐색
# - Supabase 연결
# - CSV 데이터 업로드
# - SQL 쿼리 테스트
# - Text2SQL 시스템 구현 및 테스트

# %% [markdown]
# ## 0. 환경 변수 설정

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# OpenAI API Key 확인
if os.environ.get("OPENAI_API_KEY"):
    print("✓ OpenAI API Key가 설정되었습니다.")
else:
    print("✗ OpenAI API Key가 없습니다.")

# Supabase 설정 확인
if os.environ.get("SUPABASE_DB_URL"):
    print("✓ Supabase DB URL이 설정되었습니다.")
else:
    print("✗ Supabase DB URL이 필요합니다.")
    print("  .env 파일에 SUPABASE_DB_URL을 추가하세요.")
# Out:
# ✓ OpenAI API Key가 설정되었습니다.
# ✓ Supabase DB URL이 설정되었습니다.

# %% [markdown]
# ## 1. CSV 파일 확인 및 탐색
#
# **TODO: 팀에서 준비한 CSV 파일 경로를 입력하세요**
#
# **중요:** 여러 CSV 파일을 사용하는 경우, 테이블 간 관계(Foreign Key)를 고려하여 업로드 순서를 결정하세요.
# - 부모 테이블 → 자식 테이블 순서로 업로드

# %%
import pandas as pd

# TODO: 팀의 CSV 파일 경로를 입력하세요
# 여러 파일이 있다면 dict 형태로 구성
# 예시:
# csv_files = {
#     "table1": "../datasets/your_table1.csv",
#     "table2": "../datasets/your_table2.csv"
# }

csv_files = {
    "isms_items": "../datasets/isms_items.csv",
    "isms_defects": "../datasets/isms_defects.csv",
    # 필요한 만큼 추가
}

# CSV 파일 로드 및 확인
dataframes = {}

for table_name, file_path in csv_files.items():
    try:
        try:
            df = pd.read_csv(file_path, encoding='utf-8-sig')
        except UnicodeDecodeError:
            df = pd.read_csv(file_path, encoding='cp949')
        dataframes[table_name] = df

        print("=" * 80)
        print(f"📋 {table_name} 테이블")
        print("=" * 80)
        print(f"\n행 수: {len(df)}")
        print(f"컬럼: {list(df.columns)}")
        print(f"\n첫 5개 행:")
        print(df.head())
        print(f"\n데이터 타입:")
        print(df.dtypes)
        print("\n")

    except Exception as e:
        print(f"✗ {table_name} 로드 실패: {e}\n")

print(f"\n✓ 총 {len(dataframes)}개의 테이블 로드 완료")
# Out:
# ================================================================================
# 📋 isms_items 테이블
# ================================================================================
#
# 행 수: 65
# 컬럼: ['분야', '분야명', '항목번호', '항목명', '상세내용', '주요 확인사항']
#
# 첫 5개 행:
#      분야          분야명   항목번호        항목명  \
# 0  1.1.   관리체계 기반 마련  1.1.1    경영진의 참여
# 1  1.1.   관리체계 기반 마련  1.1.2  최고책임자의 지정
# 2  1.1.   관리체계 기반 마련  1.1.3      조직 구성
# 3  1.1.   관리체계 기반 마련  1.1.4     범위 설정
# 4  1.1.   관리체계 기반 마련  1.1.5      정책 수립
#
#                                                 상세내용  \
# 0  최고경영자는 정보보호 및 개인정보보호 관리체계의 수립과 운영활동 전반에 경영진의 참...
# 1  최고경영자는 정보보호 업무를 총괄하는 정보보호 최고책임자와 개인정보보호 업무를 총괄...
# 2       최고경영자는 정보보호의 효과적 구현을 위한 실무조직을 구성하여 운영하여야 한다.
# 3  조직의 핵심 서비스를 고려하여 관리체계 범위를 설정하고, 관련된 서비스를 비롯하여 ...
# 4  정보보호 정책 및 시행문서를 수립∙작성하며, 이때 조직의 정보보호 방침 및 방향을 ...
#
#                                              주요 확인사항
# 0  정보보호 및 개인정보보호 관리체계의 수립 및 운영활동 전반에 경영진의 참여가 이루어...
# 1  최고경영자는 정보보호 및 개인정보보호 처리에 관한 업무를 총괄하여 책임질 최고책임자...
# 2  조직의 정보보호 활동을 체계적으로 이행하기 위해 전문성을 갖춘 실무조직을 구성하여 ...
# 3  조직의 핵심 서비스에 영향을 줄 수 있는 핵심자산을 포함하도록 관리체계 범위를 설정...
# 4  조직이 수행하는 모든 정보보호 활동의 근거를 포함하는 최상위 수준의 정보보호 정책을...
#
# 데이터 타입:
# 분야         str
# 분야명        str
# 항목번호       str
# 항목명        str
# 상세내용       str
# 주요 확인사항    str
# dtype: object
#
#
# ================================================================================
# 📋 isms_defects 테이블
# ================================================================================
#
# 행 수: 190
# 컬럼: ['통제분야', '통제영역', '통제항목', '결함수']
#
# 첫 5개 행:
#           통제분야                 통제영역                    통제항목  결함수
# 0  0. 정보보호관리과정  1. 정보보호 정책수립 및 범위설정          1.1 정보보호정책의 수립    0
# 1  0. 정보보호관리과정  1. 정보보호 정책수립 및 범위설정                1.2 범위설정    0
# 2  0. 정보보호관리과정     2. 경영진 책임 및 조직구성              2.1 경영진 참여    0
# 3  0. 정보보호관리과정     2. 경영진 책임 및 조직구성  2.2 정보보호 조직 구성 및 자원 할당    0
# 4  0. 정보보호관리과정              3. 위험관리     3.1 위험관리 방법 및 계획 수립    1
#
# 데이터 타입:
# 통제분야      str
# 통제영역      str
# 통제항목      str
# 결함수     int64
# dtype: object
#
#
#
# ✓ 총 2개의 테이블 로드 완료

# %% [markdown]
# ## 2. 데이터 탐색 및 통계
#
# **TODO: 팀 데이터에 맞는 탐색 쿼리를 작성하세요**

# %%
# TODO: 각 테이블의 주요 통계를 확인하세요
# 예시:
# - 특정 컬럼의 고유값 개수
# - 카테고리별 데이터 분포
# - 결측치 확인

for table_name, df in dataframes.items():
    print(f"\n{'='*80}")
    print(f"📊 {table_name} 통계")
    print("="*80)

    # 기본 통계
    print("\n[기본 정보]")
    print(df.info())

    # 결측치 확인
    print("\n[결측치]")
    null_counts = df.isnull().sum()
    if null_counts.sum() > 0:
        print(null_counts[null_counts > 0])
    else:
        print("결측치 없음")

    # TODO: 팀 데이터에 맞는 추가 탐색 코드를 작성하세요
    # 예시:
    # print("\n[카테고리 분포]")
    # print(df['YOUR_COLUMN'].value_counts())
# Out:
# ================================================================================
# 📊 isms_items 통계
# ================================================================================
#
# [기본 정보]
# <class 'pandas.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   분야       65 non-null     str
#  1   분야명      65 non-null     str
#  2   항목번호     65 non-null     str
#  3   항목명      65 non-null     str
#  4   상세내용     65 non-null     str
#  5   주요 확인사항  65 non-null     str
# dtypes: str(6)
# memory usage: 60.8 KB
# None
#
# [결측치]
# 결측치 없음
#
# ================================================================================
# 📊 isms_defects 통계
# ================================================================================
#
# [기본 정보]
# <class 'pandas.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   통제분야    190 non-null    str
#  1   통제영역    190 non-null    str
#  2   통제항목    190 non-null    str
#  3   결함수     190 non-null    int64
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
# None
#
# [결측치]
# 결측치 없음

# %% [markdown]
# ## 3. Supabase PostgreSQL 연결

# %%
from langchain_community.utilities import SQLDatabase

supabase_db_url = os.getenv("SUPABASE_DB_URL")

if not supabase_db_url:
    raise Exception("SUPABASE_DB_URL이 설정되지 않았습니다. .env 파일을 확인하세요.")

print("Supabase PostgreSQL 연결 중...\n")

try:
    # LangChain SQLDatabase로 PostgreSQL 연결
    db = SQLDatabase.from_uri(supabase_db_url)

    print("✓ PostgreSQL 연결 성공!\n")
    print("현재 테이블 목록:")
    tables = db.get_usable_table_names()
    print(tables)

except Exception as e:
    print(f"✗ 연결 실패: {e}")
    raise
# Out:
# C:\Users\wwkdr\AppData\Local\Temp\ipykernel_33472\1442992373.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# Supabase PostgreSQL 연결 중...
#
# ✓ PostgreSQL 연결 성공!
#
# 현재 테이블 목록:
# ['departments', 'office_floors', 'organizations']

# %% [markdown]
# ## 4. Supabase에 CSV 데이터 업로드
#
# ### Supabase 대시보드 (GUI)
# 1. Supabase 대시보드 접속
# 2. Table Editor → Import data from CSV
# 3. **반드시 테이블 관계 순서대로 업로드** (부모 → 자식)
# 4. Foreign Key 에러 발생 시 순서를 재확인

# %% [markdown]
# ## 5. 업로드 확인 및 스키마 탐색

# %%
# 데이터베이스 다시 연결 (업로드 후 스키마 갱신)
db = SQLDatabase.from_uri(supabase_db_url)

print("=== 데이터베이스 스키마 ===")
print(db.table_info)

print("\n" + "="*80 + "\n")

# 각 테이블의 샘플 데이터
for table in db.get_usable_table_names():
    print(f"{table} 테이블 샘플:")
    try:
        result = db.run(f"SELECT * FROM {table} LIMIT 3")
        print(result)
    except Exception as e:
        print(f"조회 실패: {e}")
    print()
# Out:
# === 데이터베이스 스키마 ===
#
# CREATE TABLE departments (
# 	dept_id BIGINT,
# 	dept_name TEXT,
# 	org_id BIGINT,
# 	dept_code TEXT,
# 	phone TEXT,
# 	fax TEXT,
# 	floor_location TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from departments table:
# dept_id	dept_name	org_id	dept_code	phone	fax	floor_location	description
# 101	홍보담당관	2	D101	041-521-2080	041-521-2089	본관 8층	홍보업무 총괄 및 보도자료 관리
# 102	감사관	2	D102	041-521-2040	041-521-2049	본관 4층	감사업무 총괄 및 청렴윤리 관리
# 103	스마트도시추진과	2	D103	041-521-2205	041-521-2209	본관 7층	스마트도시 정책 및 AI산업 추진
# */
#
#
# CREATE TABLE isms_defects (
# 	"통제분야" TEXT,
# 	"통제영역" TEXT,
# 	"통제항목" TEXT,
# 	"결함수" BIGINT
# )
#
# /*
# 3 rows from isms_defects table:
# 통제분야	통제영역	통제항목	결함수
# 0. 정보보호관리과정	1. 정보보호 정책수립 및 범위설정	1.1 정보보호정책의 수립	0
# 0. 정보보호관리과정	1. 정보보호 정책수립 및 범위설정	1.2 범위설정	0
# 0. 정보보호관리과정	2. 경영진 책임 및 조직구성	2.1 경영진 참여	0
# */
#
#
# CREATE TABLE isms_items (
# 	"분야" TEXT,
# 	"분야명" TEXT,
# 	"항목번호" TEXT,
# 	"항목명" TEXT,
# 	"상세내용" TEXT,
# 	"주요 확인사항" TEXT
# )
#
# /*
# 3 rows from isms_items table:
# 분야	분야명	항목번호	항목명	상세내용	주요 확인사항
# 1.1.	 관리체계 기반 마련	1.1.1	경영진의 참여	최고경영자는 정보보호 및 개인정보보호 관리체계의 수립과 운영활동 전반에 경영진의 참여가 이루어질 수 있도록 보고 및 의사결정 체계를 수립하여 운영하여야 한다.	정보보호 및 개인정보보호 관리체계의 수립 및 운영활동 전반에 경영진의 참여가 이루어질 수 있도록 보고 및 의사결정 등의 책임과 역할을 문서화하고 있는가?
# 경영진이 정보보호 및 개인
# 1.1.	 관리체계 기반 마련	1.1.2	최고책임자의 지정	최고경영자는 정보보호 업무를 총괄하는 정보보호 최고책임자와 개인정보보호 업무를 총괄하는 개인정보보호 책임자를 예산∙인력 등 자원을 할당할 수 있는 임원급으로 지정하여야 한다.	최고경영자는 정보보호 및 개인정보보호 처리에 관한 업무를 총괄하여 책임질 최고책임자를 공식적으로 지정하고 있는가?
# 정보보호 최고책임자 및 개인정보 보호책임자는 예산, 인력 등 자원
# 1.1.	 관리체계 기반 마련	1.1.3	조직 구성	최고경영자는 정보보호의 효과적 구현을 위한 실무조직을 구성하여 운영하여야 한다.	조직의 정보보호 활동을 체계적으로 이행하기 위해 전문성을 갖춘 실무조직을 구성하여 운영하고 있는가?
# */
#
#
# CREATE TABLE office_floors (
# 	floor_id BIGINT,
# 	building_name TEXT,
# 	floor_number BIGINT,
# 	floor_name TEXT,
# 	main_departments TEXT,
# 	facilities TEXT,
# 	area_type TEXT
# )
#
# /*
# 3 rows from office_floors table:
# floor_id	building_name	floor_number	floor_name	main_departments	facilities	area_type
# 1	천안시청 본관	1	본관 1층	민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과	청사카페,민원실,대기공간	민원서비스층
# 2	천안시청 본관	2	본관 2층	미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과	도솔도서관	행정문화층
# 3	천안시청 본관	3	본관 3층	여성가족과,아동보육과	콜센터,대회의실,천안시정공무원노동조합	복지행정층
# */
#
#
# CREATE TABLE organizations (
# 	org_id BIGINT,
# 	org_name TEXT,
# 	org_type TEXT,
# 	parent_org_id TEXT,
# 	org_level BIGINT,
# 	org_code TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from organizations table:
# org_id	org_name	org_type	parent_org_id	org_level	org_code	description
# 1	천안시청	시청	None	1	CA001	천안시 본청
# 2	부시장 직속	직속	1	2	CA002	부시장 직속 부서
# 3	기획조정실	실	1	2	CA003	정책 기획 및 예산 총괄
# */
#
# ================================================================================
#
# departments 테이블 샘플:
# [(101, '홍보담당관', 2, 'D101', '041-521-2080', '041-521-2089', '본관 8층', '홍보업무 총괄 및 보도자료 관리'), (102, '감사관', 2, 'D102', '041-521-2040', '041-521-2049', '본관 4층', '감사업무 총괄 및 청렴윤리 관리'), (103, '스마트도시추진과', 2, 'D103', '041-521-2205', '041-521-2209', '본관 7층', '스마트도시 정책 및 AI산업 추진')]
#
# isms_defects 테이블 샘플:
# [('0. 정보보호관리과정', '1. 정보보호 정책수립 및 범위설정', '1.1 정보보호정책의 수립', 0), ('0. 정보보호관리과정', '1. 정보보호 정책수립 및 범위설정', '1.2 범위설정', 0), ('0. 정보보호관리과정', '2. 경영진 책임 및 조직구성', '2.1 경영진 참여', 0)]
#
# isms_items 테이블 샘플:
# [('1.1.', ' 관리체계 기반 마련', '1.1.1', '경영진의 참여', '최고경영자는 정보보호 및 개인정보보호 관리체계의 수립과 운영활동 전반에 경영진의 참여가 이루어질 수 있도록 보고 및 의사결정 체계를 수립하여 운영하여야 한다.', '정보보호 및 개인정보보호 관리체계의 수립 및 운영활동 전반에 경영진의 참여가 이루어질 수 있도록 보고 및 의사결정 등의 책임과 역할을 문서화하고 있는가?\n경영진이 정보보호 및 개인정보보호 활동에 관한 의사결정에 적극적으로 참여할 수 있는 보고, 검토 및 승인 절차를 수립∙이행하고 있는가?'), ('1.1.', ' 관리체계 기반 마련', '1.1.2', '최고책임자의 지정', '최고경영자는 정보보호 업무를 총괄하는 정보보호 최고책임자와 개인정보보호 업무를 총괄하는 개인정보보호 책임자를 예산∙인력 등 자원을 할당할 수 있는 임원급으로 지정하여야 한다.', '최고경영자는 정보보호 및 개인정보보호 처리에 관한 업무를 총괄하여 책임질 최고책임자를 공식적으로 지정하고 있는가?\n정보보호 최고책임자 및 개인정보 보호책임자는 예산, 인력 등 자원을 할당할 수 있는 임원급으로 지정하고 있으며 관련 법령에 따른 자격요건을 충족하고 있는가?'), ('1.1.', ' 관리체계 기반 마련', '1.1.3', '조직 구성', '최고경영자는 정보보호의 효과적 구현을 위한 실무조직을 구성하여 운영하여야 한다.', '조직의 정보보호 활동을 체계적으로 이행하기 위해 전문성을 갖춘 실무조직을 구성하여 운영하고 있는가?')]
#
# office_floors 테이블 샘플:
# [(1, '천안시청 본관', 1, '본관 1층', '민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과', '청사카페,민원실,대기공간', '민원서비스층'), (2, '천안시청 본관', 2, '본관 2층', '미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과', '도솔도서관', '행정문화층'), (3, '천안시청 본관', 3, '본관 3층', '여성가족과,아동보육과', '콜센터,대회의실,천안시정공무원노동조합', '복지행정층')]
#
# organizations 테이블 샘플:
# [(1, '천안시청', '시청', None, 1, 'CA001', '천안시 본청'), (2, '부시장 직속', '직속', '1', 2, 'CA002', '부시장 직속 부서'), (3, '기획조정실', '실', '1', 2, 'CA003', '정책 기획 및 예산 총괄')]

# %% [markdown]
# ## 6. SQL 쿼리 테스트
#
# **TODO: 팀 데이터에 맞는 SQL 쿼리를 작성하여 테스트하세요**

# %%
# TODO: 기본 조회 쿼리 작성
# 예시: 특정 조건으로 데이터 조회

query = """
SELECT "항목번호", "항목명", "분야명"
FROM isms_items
LIMIT 5;
"""

print("실행 쿼리:")
print(query)
print("\n결과:")

try:
    result = db.run(query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT "항목번호", "항목명", "분야명"
# FROM isms_items
# LIMIT 5;
#
#
# 결과:
# [('1.1.1', '경영진의 참여', ' 관리체계 기반 마련'), ('1.1.2', '최고책임자의 지정', ' 관리체계 기반 마련'), ('1.1.3', '조직 구성', ' 관리체계 기반 마련'), ('1.1.4', '범위 설정 ', ' 관리체계 기반 마련'), ('1.1.5', '정책 수립', ' 관리체계 기반 마련')]

# %%
# TODO: JOIN 쿼리 작성 (여러 테이블을 사용하는 경우)
# 예시: 두 테이블을 조인하여 데이터 조회

join_query = """
SELECT i."항목번호", i."항목명", d."통제항목", d."결함수"
FROM isms_items i
JOIN isms_defects d ON d."통제항목" LIKE i."항목번호" || '%'
LIMIT 5;
"""

print("실행 쿼리:")
print(join_query)
print("\n결과:")

try:
    result = db.run(join_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT i."항목번호", i."항목명", d."통제항목", d."결함수"
# FROM isms_items i
# JOIN isms_defects d ON d."통제항목" LIKE i."항목번호" || '%'
# LIMIT 5;
#
#
# 결과:
# [('1.1.1', '경영진의 참여', '1.1.1 정책의 승인', 1), ('1.1.2', '최고책임자의 지정', '1.1.2 정책의 공표', 0), ('1.2.1', '정보자산 식별', '1.2.1 상위 정책과의 연계성', 0), ('1.2.2', '현황 및 흐름분석', '1.2.2 정책시행 문서수립', 1), ('1.3.1', '운영현황 관리', '1.3.1 정책의 검토', 3)]

# %%
# TODO: 집계(Aggregation) 쿼리 작성
# 예시: GROUP BY, COUNT, SUM, AVG 등 사용

aggregation_query = """
SELECT "통제영역", SUM("결함수") AS "총_결함수"
FROM isms_defects
GROUP BY "통제영역"
ORDER BY "총_결함수" DESC;
"""

print("실행 쿼리:")
print(aggregation_query)
print("\n결과:")

try:
    result = db.run(aggregation_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT "통제영역", SUM("결함수") AS "총_결함수"
# FROM isms_defects
# GROUP BY "통제영역"
# ORDER BY "총_결함수" DESC;
#
#
# 결과:
# [('10.4 접근통제 영역', Decimal('30')), ('11.2 시스템 및 서비스 운영보안', Decimal('27')), ('5. 사후관리', Decimal('15')), ('11.5 악성코드 관리', Decimal('14')), ('10.2 접근권한 관리', Decimal('11')), ('8.2 구현 및 이관 보안', Decimal('11')), ('3. 위험관리', Decimal('10')), ('11.6 로그관리 및 모니터링', Decimal('10')), ('10.3 사용자 인증 및 식별', Decimal('8')), ('4.1 정보자산 식별 및 책임', Decimal('6')), ('7.1 물리적 보호구역', Decimal('4')), ('7.3 사무실 보안', Decimal('3')), ('1.3 정책의 유지관리', Decimal('3')), ('9.1 암호 정책', Decimal('3')), ('8.4 운영보안', Decimal('2')), ('4. 정보보호대책 구현', Decimal('2')), ('3.2 외부자 보안 이행', Decimal('2')), ('3.1 보안 요구사항 정의', Decimal('2')), ('8.1 접근권한 관리', Decimal('2')), ('2.1 조직 체계', Decimal('2')), ('9.2 암호키 관리', Decimal('1')), ('5.1 교육 프로그램 수립', Decimal('1')), ('1.1 정책의 승인 및 공표', Decimal('1')), ('13.2 대책 구현', Decimal('1')), ('1.2 정책의 체계', Decimal('1')), ('5.2 교육 시행 및 평가', Decimal('1')), ('8.3 접근통제 영역관리', Decimal('1')), ('6.2 인사규정', Decimal('0')), ('1.3 조직', Decimal('0')), ('7.4 침해사고 관리', Decimal('0')), ('2.1 개인정보 식별', Decimal('0')), ('5.2 개인정보 이용 및 제공', Decimal('0')), ('1. 정보보호 정책수립 및 범위설정', Decimal('0')), ('4.2 정보자산의 분류 및 취급', Decimal('0')), ('11.4 매체 보안', Decimal('0')), ('12.1 절차 및 체계', Decimal('0')), ('8.2 접속기록 관리', Decimal('0')), ('9.1 영상정보처리기기 관리', Decimal('0')), ('2. 경영진 책임 및 조직구성', Decimal('0')), ('6.1 정보보호 책임', Decimal('0')), ('5.4 개인정보 파기 시 보호조치', Decimal('0')), ('12.2 대응 및 복구', Decimal('0')), ('9.3 매체 관리', Decimal('0')), ('11.1 운영절차 및 변경관리', Decimal('0')), ('1.1 정책 및 범위', Decimal('0')), ('2.2 위험관리', Decimal('0')), ('7.2 시스템 보호', Decimal('0')), ('4.1 교정 및 개선활동', Decimal('0')), ('10.1 접근통제 정책', Decimal('0')), ('4.2 내부공유 및 교육', Decimal('0')), ('8.5 암호화 통제', Decimal('0')), ('7.1 교육 및 훈련', Decimal('0')), ('8.6 개발 보안', Decimal('0')), ('8.3 외주개발보안', Decimal('0')), ('8.1 분석 및 설계 보안관리', Decimal('0')), ('13.1 체계 구축', Decimal('0')), ('9.2 물리적 보안관리', Decimal('0')), ('11.3 전자거래 및 정보전송 보안', Decimal('0')), ('6.1 권리보장', Decimal('0')), ('5.1 개인정보 수집시 보호조치', Decimal('0')), ('3.1 개인정보보호 체계의 검토', Decimal('0')), ('2.2 역할 및 책임', Decimal('0')), ('12.3 사후관리', Decimal('0')), ('7.3 위탁업무 관리', Decimal('0')), ('5.3 개인정보 보유 시 보호조치', Decimal('0')), ('1.2 경영진의 책임', Decimal('0')), ('7.2 개인정보취급자 관리', Decimal('0'))]

# %% [markdown]
# ## 7. Text2SQL 함수 구현
#
# **TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요**

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model("gpt-5.4-mini")

def text_to_sql(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문을 SQL로 변환
    """
    # TODO: 시스템 프롬프트를 팀 데이터에 맞게 수정하세요
    system_prompt = f"""
    당신은 SQL 전문가입니다.
    사용자의 질문을 SQL 쿼리로 변환하세요.

    데이터베이스 스키마:
    {db.table_info}

    규칙:
    - PostgreSQL 문법 사용
    - SELECT 쿼리만 생성 (INSERT, UPDATE, DELETE 금지)
    - SQL 코드만 반환 (설명 불필요)
    - 코드 블록(```) 없이 순수 SQL만 반환
    - 세미콜론(;)으로 끝내기
    - 모든 한글 컬럼명은 반드시 큰따옴표("")로 감싸야 합니다.
        - 올바른 예: SELECT "항목번호", "항목명" FROM isms_items
    - isms_items 테이블(부모)과 isms_defects 테이블(자식)을 JOIN 할 때, "항목번호"(예: 1.1.1)와 "통제항목"(예: 1.1.1 정책의 수립)의 형태가 다르므로 반드시 LIKE 문법을 사용하여 연결해야 합니다.
        - 올바른 JOIN 예시: JOIN isms_defects d ON d."통제항목" LIKE i."항목번호" || '%'
    - WHERE 조건에서 글자를 검색할 때는 띄어쓰기 오류를 방지하기 위해 '=' 대신 'LIKE'와 '%'를 사용하세요. 
        - 올바른 예: WHERE i."분야명" LIKE '%관리체계 기반 마련%'
    - SUM 등 합계를 구할 때는 결과가 없을 때 None이 뜨지 않도록 COALESCE를 사용하세요. 
        - 올바른 예: COALESCE(SUM(d."결함수"), 0)
    - 통제항목과 항목번호가 정확히 일치하는(=) 조건으로 조인해 주세요.

    사용 가능한 SQL 문법:
    - JOIN (INNER, LEFT, RIGHT, FULL)
    - GROUP BY, HAVING
    - 집계 함수 (COUNT, SUM, AVG, MIN, MAX)
    - 서브쿼리
    - WHERE, ORDER BY, LIMIT
    - CTE (WITH 절)
    - 윈도우 함수
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=question)
    ]

    response = llm.invoke(messages)
    sql = response.content.strip()

    # 코드 블록 제거
    if sql.startswith("```"):
        lines = sql.split("\n")
        sql = "\n".join(lines[1:-1]) if len(lines) > 2 else sql
        sql = sql.replace("sql", "").replace("```", "").strip()

    return sql

print("✓ Text2SQL 함수 준비 완료")
# Out:
# ✓ Text2SQL 함수 준비 완료

# %% [markdown]
# ## 8. Text2SQL 테스트
#
# **TODO: 팀 데이터에 맞는 자연어 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "가장 결함이 많은 통제영역 3개 알려줘."

print(f"질문: {question}\n")
print("="*80)

# SQL 생성
sql = text_to_sql(question, db)
print(f"\n생성된 SQL:")
print(sql)
print()

# SQL 실행
print("="*80)
print("\n실행 결과:")
try:
    result = db.run(sql)
    print(result)
except Exception as e:
    print(f"실행 오류: {e}")
# Out:
# 질문: 가장 결함이 많은 통제영역 3개 알려줘.
#
# ================================================================================
#
# 생성된 SQL:
# SELECT "통제영역", COALESCE(SUM("결함수"), 0) AS "총결함수"
# FROM isms_defects
# GROUP BY "통제영역"
# ORDER BY "총결함수" DESC
# LIMIT 3;
#
# ================================================================================
#
# 실행 결과:
# [('10.4 접근통제 영역', Decimal('30')), ('11.2 시스템 및 서비스 운영보안', Decimal('27')), ('5. 사후관리', Decimal('15'))]

# %% [markdown]
# ## 9. 완전한 Text2SQL 시스템 (SQL 실행 + 자연어 답변)
#
# **TODO: 답변 생성 프롬프트를 팀 데이터에 맞게 수정하세요**

# %%
def query_database(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문 → SQL 생성 → 실행 → 자연어 답변
    """
    # 1. SQL 생성
    print(f"[1] SQL 생성 중...")
    sql = text_to_sql(question, db)
    print(f"    {sql}\n")

    # 2. SQL 실행
    print(f"[2] SQL 실행 중...")
    try:
        result = db.run(sql)
        print(f"    실행 완료\n")
    except Exception as e:
        return f"SQL 실행 오류: {e}"

    # 3. 자연어 답변 생성
    print(f"[3] 답변 생성 중...")

    # TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요
    system_prompt = """
    당신은 ISMS-P 및 보안 결함 통계 데이터 분석 전문가입니다.
    SQL 쿼리 결과를 기반으로 사용자의 질문에 자연스럽게 답변하세요.
    답변은 명확하고 이해하기 쉽게 작성하세요.
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=f"""
        질문: {question}

        실행한 SQL:
        {sql}

        쿼리 결과:
        {result}

        위 결과를 바탕으로 질문에 답변해주세요.
        """)
    ]

    response = llm.invoke(messages)
    return response.content

print("✓ 완전한 Text2SQL 시스템 준비 완료")
# Out:
# ✓ 완전한 Text2SQL 시스템 준비 완료

# %%
from IPython.display import Markdown, display

# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "가장 결함이 많이 나오는 통제영역이 어디야?"

print(f"질문: {question}\n")
print("="*80 + "\n")

answer = query_database(question, db)

print("\n" + "="*80)
print("\n답변:")
display(Markdown(answer))
# Out:
# 질문: 가장 결함이 많이 나오는 통제영역이 어디야?
#
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "통제영역", COALESCE(SUM("결함수"), 0) AS "총결함수"
# FROM isms_defects
# GROUP BY "통제영역"
# ORDER BY "총결함수" DESC
# LIMIT 1;
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# ================================================================================
#
# 답변:
# 가장 결함이 많이 나오는 통제영역은 **10.4 접근통제 영역**입니다.
# 총 **30건**의 결함이 집계되었습니다.

# %% [markdown]
# ## 10. 다양한 질문으로 테스트
#
# **TODO: 최소 5개 이상의 다양한 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 다양한 질문들을 작성하세요
# 기본 조회, JOIN, 집계, 정렬 등 다양한 유형의 질문 포함

questions = [
    "인증기준 1.1.1 항목의 이름과 상세내용이 뭐야?",
    "전체 결함수의 총합은 몇 개야?",
    "가장 결함이 많이 발생한 통제영역 Top 3와 각각의 결함수를 알려줘.",
    "가장 결함수가 적게 발생한 통제영역은 어디고, 결함수는 어떻게 돼?",
    "주요 확인사항에 '최고경영자'라는 단어가 포함된 항목의 번호와 이름을 모두 찾아줘."
]

for q in questions:
    print(f"\n{'='*80}")
    print(f"질문: {q}")
    print("="*80 + "\n")

    try:
        answer = query_database(q, db)
        print("\n답변:")
        display(Markdown(answer))
    except Exception as e:
        print(f"오류: {e}")
# Out:
# ================================================================================
# 질문: 인증기준 1.1.1 항목의 이름과 상세내용이 뭐야?
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "항목명", "상세내용" FROM isms_items WHERE "항목번호" LIKE '1.1.1%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 인증기준 **1.1.1**의 항목명은 **“경영진의 참여”**입니다.
#
# 상세내용은 다음과 같습니다.
# **“최고경영자는 정보보호 및 개인정보보호 관리체계의 수립과 운영활동 전반에 경영진의 참여가 이루어질 수 있도록 보고 및 의사결정 체계를 수립하여 운영하여야 한다.”**
# ================================================================================
# 질문: 전체 결함수의 총합은 몇 개야?
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT COALESCE(SUM("결함수"), 0) AS "전체 결함수 총합"
# FROM isms_defects;
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 전체 결함수의 총합은 **174개**입니다.
# ================================================================================
# 질문: 가장 결함이 많이 발생한 통제영역 Top 3와 각각의 결함수를 알려줘.
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "통제영역", COALESCE(SUM("결함수"), 0) AS "결함수"
# FROM isms_defects
# GROUP BY "통제영역"
# ORDER BY "결함수" DESC
# LIMIT 3;
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 결함이 가장 많이 발생한 통제영역 Top 3는 다음과 같습니다.
#
# 1. **10.4 접근통제 영역** — **30건**
# 2. **11.2 시스템 및 서비스 운영보안** — **27건**
# 3. **5. 사후관리** — **15건**
#
# 즉, **접근통제 영역**에서 결함이 가장 많이 발생했고, 그 다음으로 **시스템 및 서비스 운영보안**, **사후관리** 순으로 나타났습니다.
# ================================================================================
# 질문: 가장 결함수가 적게 발생한 통제영역은 어디고, 결함수는 어떻게 돼?
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "통제영역", "결함수"
# FROM isms_defects
# WHERE "결함수" = (
#     SELECT MIN("결함수")
#     FROM isms_defects
# )
# ORDER BY "통제영역";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 쿼리 결과상 **가장 결함수가 적은 통제영역은 결함수 0건인 모든 통제영역**입니다.
# 즉, **최소 결함수는 0**이고, 결과에 나온 항목들은 모두 이 최소값에 해당합니다.
#
# 다만 현재 결과에는 **같은 통제영역이 여러 번 반복**되어 있어서, 실제로는 **결함수 0인 통제영역들이 다수 존재한다**고 보는 것이 맞습니다.
#
# 예시로 일부만 보면:
# - 1. 정보보호 정책수립 및 범위설정: 0
# - 1.1 정책 및 범위: 0
# - 10.1 접근통제 정책: 0
# - 11.1 운영절차 및 변경관리: 0
# - 5.1 개인정보 수집시 보호조치: 0
# - 8.4 운영보안: 0
# - 9.3 매체 관리: 0
#
# 정리하면:
# - **가장 적은 결함수:** 0건
# - **해당 통제영역:** 결과에 나온 **모든 결함수 0인 통제영역들**
#
# 원하시면 제가 이 결과를 **중복 없이 통제영역별로 정리해서** 다시 보여드릴게요.
# ================================================================================
# 질문: 주요 확인사항에 '최고경영자'라는 단어가 포함된 항목의 번호와 이름을 모두 찾아줘.
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "항목번호", "항목명"
# FROM isms_items
# WHERE "주요 확인사항" LIKE '%최고경영자%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 주요 확인사항에 **'최고경영자'**라는 단어가 포함된 항목은 다음과 같습니다.
#
# - **1.1.2** — 최고책임자의 지정
# - **1.1.5** — 정책 수립

# %% [markdown]
# ## 프로젝트 점검 체크리스트
#
# **완료한 항목을 확인하세요:**
#
# - [ ] CSV 파일 준비 및 데이터 확인 완료
# - [ ] CSV 데이터 탐색 및 통계 분석 완료
# - [ ] Supabase 연결 완료
# - [ ] CSV 데이터 업로드 완료
# - [ ] 직접 작성한 SQL 쿼리 테스트 완료 (최소 3개)
# - [ ] Text2SQL 함수 구현 및 프롬프트 수정 완료
# - [ ] 자연어 질문으로 SQL 생성 테스트 완료
# - [ ] 완전한 Text2SQL 시스템 (답변 생성) 테스트 완료
# - [ ] 최소 5개 이상의 다양한 질문으로 테스트 완료
#
# ---
#
# ## 추가 개선 아이디어
#
# 1. **프롬프트 개선**: SQL 생성 정확도 향상을 위한 예시 추가
# 2. **에러 핸들링**: SQL 오류 발생 시 재시도 로직 구현
# 3. **쿼리 검증**: 생성된 SQL이 안전한지 검증하는 로직 추가
# 4. **결과 포맷팅**: 테이블 형태로 결과 출력
# 5. **쿼리 히스토리**: 실행한 쿼리와 결과를 저장하여 재사용
# 6. **고급 SQL**: 서브쿼리, CTE, 윈도우 함수 활용
