# %% [markdown]
# # **3일차 팀 프로젝트: 테이블 데이터 조회 시스템 구축**
#
# ## 프로젝트 목표
# 1. 팀에서 선정한 CSV 테이블 데이터를 Supabase에 적재
# 2. SQL 쿼리로 데이터 조회 테스트
# 3. Text2SQL 시스템 구현 및 테스트
#
# ## 구현 단계
# - 환경 설정 확인
# - CSV 파일 확인 및 탐색
# - Supabase 연결
# - CSV 데이터 업로드
# - SQL 쿼리 테스트
# - Text2SQL 시스템 구현 및 테스트

# %% [markdown]
# ## 0. 환경 변수 설정

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# OpenAI API Key 확인
if os.environ.get("OPENAI_API_KEY"):
    print("✓ OpenAI API Key가 설정되었습니다.")
else:
    print("✗ OpenAI API Key가 없습니다.")

# Supabase 설정 확인
if os.environ.get("SUPABASE_DB_URL"):
    print("✓ Supabase DB URL이 설정되었습니다.")
else:
    print("✗ Supabase DB URL이 필요합니다.")
    print("  .env 파일에 SUPABASE_DB_URL을 추가하세요.")
# Out:
# ✓ OpenAI API Key가 설정되었습니다.
# ✓ Supabase DB URL이 설정되었습니다.

# %% [markdown]
# ## 1. CSV 파일 확인 및 탐색
#
# **TODO: 팀에서 준비한 CSV 파일 경로를 입력하세요**
#
# **중요:** 여러 CSV 파일을 사용하는 경우, 테이블 간 관계(Foreign Key)를 고려하여 업로드 순서를 결정하세요.
# - 부모 테이블 → 자식 테이블 순서로 업로드

# %%
import pandas as pd

# TODO: 팀의 CSV 파일 경로를 입력하세요
# 여러 파일이 있다면 dict 형태로 구성
# 예시:
# csv_files = {
#     "table1": "../datasets/your_table1.csv",
#     "table2": "../datasets/your_table2.csv"
# }

csv_files = {
    "certification_status": "../datasets/ismsp_certification_status.csv",
    # 필요한 만큼 추가
}

# CSV 파일 로드 및 확인
dataframes = {}

for table_name, file_path in csv_files.items():
    try:
        df = pd.read_csv(file_path, encoding="cp949")
        dataframes[table_name] = df

        print("=" * 80)
        print(f"📋 {table_name} 테이블")
        print("=" * 80)
        print(f"\n행 수: {len(df)}")
        print(f"컬럼: {list(df.columns)}")
        print(f"\n첫 5개 행:")
        print(df.head())
        print(f"\n데이터 타입:")
        print(df.dtypes)
        print("\n")

    except Exception as e:
        print(f"✗ {table_name} 로드 실패: {e}\n")

print(f"\n✓ 총 {len(dataframes)}개의 테이블 로드 완료")
# Out:
# ================================================================================
# 📋 certification_status 테이블
# ================================================================================
#
# 행 수: 1274
# 컬럼: ['인증구분', '인증번호', '기업명', '인증의 범위', '유효기간']
#
# 첫 5개 행:
#      인증구분                  인증번호           기업명  \
# 0  ISMS-P  ISMS-P-KISA-2026-025   (주)씨어스테크놀로지
# 1  ISMS-P  ISMS-P-KISA-2026-024     한국산업기술시험원
# 2    ISMS    ISMS-KISA-2026-068  씨제이씨지브이 주식회사
# 3    ISMS    ISMS-KISA-2026-067   (주)티디에이치컴퍼니
# 4    ISMS    ISMS-KISA-2026-066      건양사이버대학교
#
#                                       인증의 범위                   유효기간
# 0                심질환 모니터링 서비스(Cardio) 인프라 운영  2026-04-15~2029-04-14
# 1                         대표누리집 및 시험인증서비스 부문  2026-04-15~2029-04-14
# 2     온라인 서비스(영화예매/매점판매, 회사홈페이지), 광고/미디어 서비스  2026-04-15~2029-04-14
# 3  온라인 쇼핑몰 운영(오까네)(정보통신망법 제47조의7에 따른 인증의 특례)  2026-04-15~2029-04-14
# 4                                 원격교육시스템 운영  2026-04-15~2029-04-14
#
# 데이터 타입:
# 인증구분      str
# 인증번호      str
# 기업명       str
# 인증의 범위    str
# 유효기간      str
# dtype: object
#
#
#
# ✓ 총 1개의 테이블 로드 완료

# %% [markdown]
# ## 2. 데이터 탐색 및 통계
#
# **TODO: 팀 데이터에 맞는 탐색 쿼리를 작성하세요**

# %%
# TODO: 각 테이블의 주요 통계를 확인하세요
# 예시:
# - 특정 컬럼의 고유값 개수
# - 카테고리별 데이터 분포
# - 결측치 확인

for table_name, df in dataframes.items():
    print(f"\n{'='*80}")
    print(f"📊 {table_name} 통계")
    print("="*80)

    # 기본 통계
    print("\n[기본 정보]")
    print(df.info())

    #ISMS,ISMS-P 인증구분
    print("\n[ISMS/ISMS-P 인증구분]")
    print(df['인증구분'].value_counts())
    

    # TODO: 팀 데이터에 맞는 추가 탐색 코드를 작성하세요
    # 예시:
    # print("\n[카테고리 분포]")
    # print(df['YOUR_COLUMN'].value_counts())
# Out:
# ================================================================================
# 📊 certification_status 통계
# ================================================================================
#
# [기본 정보]
# <class 'pandas.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   인증구분    1274 non-null   str
#  1   인증번호    1274 non-null   str
#  2   기업명     1274 non-null   str
#  3   인증의 범위  1274 non-null   str
#  4   유효기간    1274 non-null   str
# dtypes: str(5)
# memory usage: 225.9 KB
# None
#
# [ISMS/ISMS-P 인증구분]
# 인증구분
# ISMS      955
# ISMS-P    319
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Supabase PostgreSQL 연결

# %%
from langchain_community.utilities import SQLDatabase

supabase_db_url = os.getenv("SUPABASE_DB_URL")

if not supabase_db_url:
    raise Exception("SUPABASE_DB_URL이 설정되지 않았습니다. .env 파일을 확인하세요.")

print("Supabase PostgreSQL 연결 중...\n")

try:
    # LangChain SQLDatabase로 PostgreSQL 연결
    db = SQLDatabase.from_uri(supabase_db_url)

    print("✓ PostgreSQL 연결 성공!\n")
    print("현재 테이블 목록:")
    tables = db.get_usable_table_names()
    print(tables)

except Exception as e:
    print(f"✗ 연결 실패: {e}")
    raise
# Out:
# C:\Users\hk168\AppData\Local\Temp\ipykernel_7240\1442992373.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# Supabase PostgreSQL 연결 중...
#
# ✓ PostgreSQL 연결 성공!
#
# 현재 테이블 목록:
# ['departments', 'ismsp_certification_status', 'office_floors', 'organizations']

# %% [markdown]
# ## 4. Supabase에 CSV 데이터 업로드
#
# ### Supabase 대시보드 (GUI)
# 1. Supabase 대시보드 접속
# 2. Table Editor → Import data from CSV
# 3. **반드시 테이블 관계 순서대로 업로드** (부모 → 자식)
# 4. Foreign Key 에러 발생 시 순서를 재확인

# %% [markdown]
# ## 5. 업로드 확인 및 스키마 탐색

# %%
# 데이터베이스 다시 연결 (업로드 후 스키마 갱신)
db = SQLDatabase.from_uri(supabase_db_url)

print("=== 데이터베이스 스키마 ===")
print(db.table_info)

print("\n" + "="*80 + "\n")

# 각 테이블의 샘플 데이터
for table in db.get_usable_table_names():
    print(f"{table} 테이블 샘플:")
    try:
        result = db.run(f"SELECT * FROM {table} LIMIT 3")
        print(result)
    except Exception as e:
        print(f"조회 실패: {e}")
    print()
# Out:
# === 데이터베이스 스키마 ===
#
# CREATE TABLE departments (
# 	dept_id BIGINT,
# 	dept_name TEXT,
# 	org_id BIGINT,
# 	dept_code TEXT,
# 	phone TEXT,
# 	fax TEXT,
# 	floor_location TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from departments table:
# dept_id	dept_name	org_id	dept_code	phone	fax	floor_location	description
# 101	홍보담당관	2	D101	041-521-2080	041-521-2089	본관 8층	홍보업무 총괄 및 보도자료 관리
# 102	감사관	2	D102	041-521-2040	041-521-2049	본관 4층	감사업무 총괄 및 청렴윤리 관리
# 103	스마트도시추진과	2	D103	041-521-2205	041-521-2209	본관 7층	스마트도시 정책 및 AI산업 추진
# */
#
#
# CREATE TABLE ismsp_certification_status (
# 	"인증구분" TEXT,
# 	"인증번호" TEXT,
# 	"기업명" TEXT,
# 	"인증의 범위" TEXT,
# 	"유효기간" TEXT
# )
#
# /*
# 3 rows from ismsp_certification_status table:
# 인증구분	인증번호	기업명	인증의 범위	유효기간
# ISMS	ISMS-KISA-2021-157	(주) 육육걸즈	온라인 쇼핑몰 운영(육육걸즈)	2024-09-08~2027-09-07
# ISMS	ISMS-KISA-2021-156	주식회사 프라뱅	가상자산 거래소 운영(프라뱅)	2024-09-08~2027-09-07
# ISMS-P	ISMS-P-KISA-2021-028	(주)누리미디어	학회 학술지 및 한국학 콘텐츠 서비스	2024-09-01~2027-08-31
# */
#
#
# CREATE TABLE office_floors (
# 	floor_id BIGINT,
# 	building_name TEXT,
# 	floor_number BIGINT,
# 	floor_name TEXT,
# 	main_departments TEXT,
# 	facilities TEXT,
# 	area_type TEXT
# )
#
# /*
# 3 rows from office_floors table:
# floor_id	building_name	floor_number	floor_name	main_departments	facilities	area_type
# 1	천안시청 본관	1	본관 1층	민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과	청사카페,민원실,대기공간	민원서비스층
# 2	천안시청 본관	2	본관 2층	미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과	도솔도서관	행정문화층
# 3	천안시청 본관	3	본관 3층	여성가족과,아동보육과	콜센터,대회의실,천안시정공무원노동조합	복지행정층
# */
#
#
# CREATE TABLE organizations (
# 	org_id BIGINT,
# 	org_name TEXT,
# 	org_type TEXT,
# 	parent_org_id BIGINT,
# 	org_level BIGINT,
# 	org_code TEXT,
# 	description TEXT
# )
#
# /*
# 3 rows from organizations table:
# org_id	org_name	org_type	parent_org_id	org_level	org_code	description
# 1	천안시청	시청	None	1	CA001	천안시 본청
# 2	부시장 직속	직속	1	2	CA002	부시장 직속 부서
# 3	기획조정실	실	1	2	CA003	정책 기획 및 예산 총괄
# */
#
# ================================================================================
#
# departments 테이블 샘플:
# [(101, '홍보담당관', 2, 'D101', '041-521-2080', '041-521-2089', '본관 8층', '홍보업무 총괄 및 보도자료 관리'), (102, '감사관', 2, 'D102', '041-521-2040', '041-521-2049', '본관 4층', '감사업무 총괄 및 청렴윤리 관리'), (103, '스마트도시추진과', 2, 'D103', '041-521-2205', '041-521-2209', '본관 7층', '스마트도시 정책 및 AI산업 추진')]
#
# ismsp_certification_status 테이블 샘플:
# [('ISMS', 'ISMS-KISA-2021-157', '(주) 육육걸즈', '온라인 쇼핑몰 운영(육육걸즈)', '2024-09-08~2027-09-07'), ('ISMS', 'ISMS-KISA-2021-156', '주식회사 프라뱅', '가상자산 거래소 운영(프라뱅)', '2024-09-08~2027-09-07'), ('ISMS-P', 'ISMS-P-KISA-2021-028', '(주)누리미디어', '학회 학술지 및 한국학 콘텐츠 서비스', '2024-09-01~2027-08-31')]
#
# office_floors 테이블 샘플:
# [(1, '천안시청 본관', 1, '본관 1층', '민원여권과,노인복지과,허가과,복지정책과,장애인복지과,청년정책과', '청사카페,민원실,대기공간', '민원서비스층'), (2, '천안시청 본관', 2, '본관 2층', '미래전략과,일자리경제과,교육청소년과,청소행정과,K-컬처박람회추진과', '도솔도서관', '행정문화층'), (3, '천안시청 본관', 3, '본관 3층', '여성가족과,아동보육과', '콜센터,대회의실,천안시정공무원노동조합', '복지행정층')]
#
# organizations 테이블 샘플:
# [(1, '천안시청', '시청', None, 1, 'CA001', '천안시 본청'), (2, '부시장 직속', '직속', 1, 2, 'CA002', '부시장 직속 부서'), (3, '기획조정실', '실', 1, 2, 'CA003', '정책 기획 및 예산 총괄')]

# %% [markdown]
# ## 6. SQL 쿼리 테스트
#
# **TODO: 팀 데이터에 맞는 SQL 쿼리를 작성하여 테스트하세요**

# %%
# TODO: 기본 조회 쿼리 작성
# 예시: 특정 조건으로 데이터 조회

isms_query = """
SELECT 
    기업명,
    인증번호
FROM 
    ismsp_certification_status
WHERE 
    인증구분 = 'ISMS'
    AND 유효기간 LIKE '%~2026-%'
"""

ismsp_query = """
SELECT 
    기업명,
    인증번호
FROM 
    ismsp_certification_status
WHERE 
    인증구분 = 'ISMS-P'
    AND 유효기간 LIKE '%~2026-%'
"""

print("실행 쿼리:")
print(isms_query)
print("\n결과:")

try:
    result = db.run(isms_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")

print("실행 쿼리:")
print(ismsp_query)
print("\n결과:")

try:
    result = db.run(ismsp_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# SELECT
#     기업명,
#     인증번호
# FROM
#     ismsp_certification_status
# WHERE
#     인증구분 = 'ISMS'
#     AND 유효기간 LIKE '%~2026-%'
#
#
# 결과:
# [('데상트코리아(주)', 'ISMS-KISA-2020-247'), ('영남대학교의료원', 'ISMS-KISA-2020-244'), ('대구가톨릭대학교의료원', 'ISMS-KISA-2020-243'), ('경희의료원', 'ISMS-KISA-2020-242'), ('한진세이버(주)', 'ISMS-KISA-2020-238'), ('세종대학교', 'ISMS-KISA-2020-237'), ('새마을금고중앙회', 'ISMS-FSI-2020-027'), ('메리츠증권 (주)', 'ISMS-FSI-2020-026'), ('(주) 컴투스', 'ISMS-KISA-2020-233'), ('주식회사 컴투스홀딩스', 'ISMS-KISA-2020-232'), ('경상국립대학교병원', 'ISMS-KISA-2020-231'), ('(주)케이씨에이', 'ISMS-KISA-2020-228'), ('호스트웨이아이디씨(주)', 'ISMS-KISA-2020-226'), ('서울특별시 데이터센터', 'ISMS-KISA-2020-222'), ('Amazon Web Services, Inc.', 'ISMS-KISA-2020-221'), ('네이버클라우드 주식회사', 'ISMS-KISA-2020-220'), ('(주)에이프로코리아', 'ISMS-KISA-2020-219'), ('(주)아이템베이', 'ISMS-KISA-2020-217'), ('(주)멀티캠퍼스', 'ISMS-KISA-2020-213'), ('충남대학교병원', 'ISMS-KISA-2020-212'), ('주식회사 피어테크', 'ISMS-KISA-2020-210'), ('건설공제조합', 'ISMS-KISA-2020-209'), ('한림대학교성심병원', 'ISMS-KISA-2020-208'), ('(의)삼성의료재단', 'ISMS-KISA-2020-207'), ('청오디피케이(주)', 'ISMS-KISA-2020-206'), ('(주)더에스제이', 'ISMS-KISA-2020-204'), ('교보디티에스(주)', 'ISMS-KISA-2020-203'), ('한국허벌라이프(주)', 'ISMS-KISA-2020-202'), ('(주)엘지생활건강', 'ISMS-KISA-2020-200'), ('에스케이증권', 'ISMS-FSI-2020-025'), ('부산하나로카드', 'ISMS-FSI-2020-022'), ('마이비', 'ISMS-FSI-2020-021'), ('(주)이동의즐거움', 'ISMS-FSI-2020-020'), ('유진투자증권', 'ISMS-FSI-2020-019'), ('나이스평가정보', 'ISMS-FSI-2020-017'), ('에이비씨마트코리아', 'ISMS-KISA-2020-197'), ('경희사이버대학교', 'ISMS-KISA-2020-194'), ('(주)텐바이텐', 'ISMS-KISA-2020-189'), ('(주)백패커', 'ISMS-KISA-2020-187'), ('(주)셀메이트', 'ISMS-KISA-2020-186'), ('주식회사 케이티샛', 'ISMS-KISA-2020-183'), ('(의료)길의료재단', 'ISMS-KISA-2020-181'), ('양산부산대학교병원', 'ISMS-KISA-2020-178'), ('주식회사 유비케어', 'ISMS-KISA-2020-177'), ('(주)머니투데이', 'ISMS-KISA-2020-175'), ('(주)진학사', 'ISMS-KISA-2020-173'), ('한국신용카드결제(주)', 'ISMS-KISA-2020-169'), ('교보증권(주)', 'ISMS-FSI-2020-014'), ('웰컴저축은행', 'ISMS-FSI-2020-013'), ('(주)스마일게이트 알피지', 'ISMS-KISA-2020-168'), ('SK이노베이션(주)', 'ISMS-KISA-2020-166'), ('(주)레몬헬스케어', 'ISMS-KISA-2020-165'), ('(주)이니스프리', 'ISMS-KISA-2020-164'), ('(주)아모레퍼시픽', 'ISMS-KISA-2020-163'), ('삼성전자(주)', 'ISMS-KISA-2020-161'), ('연세대학교원주세브란스기독병원', 'ISMS-KISA-2020-158'), ('인제대학교 부산백병원', 'ISMS-KISA-2020-157'), ('(주) 조아라', 'ISMS-KISA-2020-151'), ('피에스앤마케팅 주식회사', 'ISMS-KISA-2020-149'), ('(주)에치와이', 'ISMS-KISA-2020-148'), ('(주)포스토피아', 'ISMS-KISA-2020-145'), ('(주)신세계인터내셔날', 'ISMS-KISA-2020-144'), ('서울디지털대학교', 'ISMS-KISA-2020-143'), ('(주)엔라인', 'ISMS-KISA-2020-142'), ('엔투비', 'ISMS-KISA-2020-141'), ('국립대학법인 인천대학교', 'ISMS-KISA-2020-137'), ('한진정보통신(주)', 'ISMS-KISA-2020-136'), ('디비손해보험', 'ISMS-FSI-2020-011'), ('신한은행', 'ISMS-FSI-2020-010'), ('경남은행', 'ISMS-FSI-2020-009'), ('충북대학교병원', 'ISMS-KISA-2020-134'), ('건국대학교병원', 'ISMS-KISA-2020-133'), ('주식회사 인벤', 'ISMS-KISA-2020-132'), ('(주)포스코디엑스', 'ISMS-KISA-2020-131'), ('디지털서울문화예술대학교', 'ISMS-KISA-2020-128'), ('한국복지사이버대학교', 'ISMS-KISA-2020-125'), ('학교법인가톨릭학원 가톨릭대학교 인천성모병원', 'ISMS-KISA-2020-124'), ('전북대학교병원', 'ISMS-KISA-2020-122'), ('(주)평화이즈', 'ISMS-KISA-2020-121'), ('(학)가톨릭대학교 서울성모병원', 'ISMS-KISA-2020-120'), ('삼성전자판매 주식회사', 'ISMS-KISA-2020-117'), ('재단법인 한국우편사업진흥원', 'ISMS-KISA-2020-115'), ('순천향대학교부속천안병원', 'ISMS-KISA-2020-111'), ('순천향대학교부속부천병원', 'ISMS-KISA-2020-110'), ('농협은행', 'ISMS-FSI-2020-006'), ('(주)우리은행', 'ISMS-FSI-2020-005'), ('지에스네오텍(주)', 'ISMS-KISA-2020-107'), ('주식회사 디지털존', 'ISMS-KISA-2020-103'), ('(주)엠게임', 'ISMS-KISA-2020-102'), ('주식회사 네시삼십삼분', 'ISMS-KISA-2020-101'), ('아시아나항공(주)', 'ISMS-KISA-2020-098'), ('주식회사 레진엔터테인먼트', 'ISMS-KISA-2020-090'), ('(주)씨제이이엔엠', 'ISMS-KISA-2020-087'), ('뉴스킨 코리아 (주)', 'ISMS-KISA-2020-084'), ('(주)휴넷', 'ISMS-KISA-2020-082'), ('(주)다우데이타', 'ISMS-KISA-2020-081'), ('오라클 코퍼레이션', 'ISMS-KISA-2020-079'), ('(주)이마트에브리데이', 'ISMS-KISA-2023-184'), ('(주)놀유니버스', 'ISMS-KISA-2023-183'), ('(주)연합인포맥스', 'ISMS-KISA-2023-182'), ('(주) 이스트소프트', 'ISMS-KISA-2023-181'), ('법원행정처', 'ISMS-KISA-2023-180'), ('(주)호텔신라', 'ISMS-KISA-2023-179'), ('(주)와이비엠넷', 'ISMS-KISA-2023-178'), ('드림라인(주)', 'ISMS-KISA-2023-177'), ('세종텔레콤(주)', 'ISMS-KISA-2023-176'), ('한국재정정보원', 'ISMS-KISA-2023-175'), ('주식회사 컴투스플랫폼', 'ISMS-KISA-2023-174'), ('(주)케이지모빌리언스', 'ISMS-FSI-2023-014'),  ...
# 실행 쿼리:
#
# SELECT
#     기업명,
#     인증번호
# FROM
#     ismsp_certification_status
# WHERE
#     인증구분 = 'ISMS-P'
#     AND 유효기간 LIKE '%~2026-%'
#
#
# 결과:
# [('넷마블(주)', 'ISMS-P-KISA-2020-047'), ('삼성웰스토리(주)', 'ISMS-P-KISA-2020-044'), ('주식회사 케이티', 'ISMS-P-KISA-2020-043'), ('(주)에듀윌', 'ISMS-P-KISA-2020-040'), ('나이스평가정보', 'ISMS-P-FSI-2020-005'), ('주식회사 스푼랩스', 'ISMS-P-KISA-2020-039'), ('대신증권 (주)', 'ISMS-P-FSI-2020-003'), ('SK에너지(주)', 'ISMS-P-KISA-2020-036'), ('(주)한국인삼공사', 'ISMS-P-KISA-2020-035'), ('주식회사 E1', 'ISMS-P-KISA-2020-034'), ('(주) 마이리얼트립', 'ISMS-P-KISA-2020-031'), ('에스비티엠 주식회사', 'ISMS-P-KISA-2020-027'), ('한국중부발전(주)', 'ISMS-P-KISA-2020-025'), ('(주)우리은행', 'ISMS-P-FSI-2020-002'), ('우정사업본부', 'ISMS-P-KISA-2020-022'), ('GS칼텍스', 'ISMS-P-KISA-2020-021'), ('주식회사 카카오페이', 'ISMS-P-FSI-2020-001'), ('주식회사 신세계라이브쇼핑', 'ISMS-P-KISA-2020-019'), ('부산정관에너지 주식회사', 'ISMS-P-KISA-2023-064'), ('에스케이브로드밴드 주식회사', 'ISMS-P-KISA-2023-063'), ('에스케이렌터카 주식회사', 'ISMS-P-KISA-2023-062'), ('한국과학기술기획평가원', 'ISMS-P-KISA-2023-061'), ('한국재정정보원', 'ISMS-P-KISA-2023-060'), ('롯데지알에스(주)', 'ISMS-P-KISA-2023-059'), ('주식회사 컴투스플랫폼', 'ISMS-P-KISA-2023-058'), ('삼성화재해상보험 (주)', 'ISMS-P-FSI-2023-016'), ('주식회사 우리카드', 'ISMS-P-FSI-2023-015'), ('롯데캐피탈 (주)', 'ISMS-P-FSI-2023-014'), ('엔에이치엔클라우드 주식회사', 'ISMS-P-KISA-2023-057'), ('엔에이치엔두레이 주식회사', 'ISMS-P-KISA-2023-056'), ('엔에이치엔 주식회사', 'ISMS-P-KISA-2023-055'), ('에이치디현대오일뱅크 주식회사', 'ISMS-P-KISA-2023-054'), ('씨제이올리브영 주식회사', 'ISMS-P-KISA-2023-053'), ('라한프라퍼티스매니지먼트 주식회사', 'ISMS-P-KISA-2023-052'), ('(주)엘지씨엔에스', 'ISMS-P-KISA-2023-051'), ('한화생명보험 (주)', 'ISMS-P-FSI-2023-013'), ('카카오뱅크', 'ISMS-P-FSI-2023-012'), ('우리금융캐피탈 주식회사', 'ISMS-P-FSI-2023-011'), ('(주)우리홈쇼핑', 'ISMS-P-KISA-2023-050'), ('주식회사 비마이프렌즈', 'ISMS-P-KISA-2023-049'), ('연세대학교', 'ISMS-P-KISA-2023-048'), ('(주)호텔롯데롯데월드', 'ISMS-P-KISA-2023-047'), ('코리아크레딧뷰로(주)', 'ISMS-P-FSI-2023-010'), ('신한투자증권(주)', 'ISMS-P-FSI-2023-009'), ('대상주식회사', 'ISMS-P-KISA-2023-046'), ('(주)키즈노트', 'ISMS-P-KISA-2023-045'), ('네이버파이낸셜 주식회사', 'ISMS-P-KISA-2023-044'), ('네이버클라우드 주식회사', 'ISMS-P-KISA-2023-043'), ('주식회사 지마켓', 'ISMS-P-KISA-2023-042'), ('코오롱인더스트리(주) FnC부문', 'ISMS-P-KISA-2023-041'), ('토스증권 주식회사', 'ISMS-P-FSI-2023-008'), ('교보생명보험주식회사', 'ISMS-P-FSI-2023-007'), ('(주)현대그린푸드', 'ISMS-P-KISA-2023-040'), ('룰루메딕 주식회사', 'ISMS-P-KISA-2023-039'), ('SK가스(주)', 'ISMS-P-KISA-2023-038'), ('씨제이올리브네트웍스 주식회사', 'ISMS-P-KISA-2023-037'), ('(주)세라젬', 'ISMS-P-KISA-2023-036'), ('주식회사 딜라이브', 'ISMS-P-KISA-2023-035'), ('행복나래 주식회사', 'ISMS-P-KISA-2023-034'), ('서울관광재단', 'ISMS-P-KISA-2023-033'), ('롯데칠성음료(주)', 'ISMS-P-KISA-2023-032'), ('주식회사펄어비스', 'ISMS-P-KISA-2023-031'), ('휴마니타스(주)', 'ISMS-P-KISA-2023-030'), ('주식회사 카카오페이증권', 'ISMS-P-FSI-2023-006'), ('주식회사 카카오스타일', 'ISMS-P-KISA-2023-029'), ('주식회사 야놀자', 'ISMS-P-KISA-2023-028'), ('주식회사 오픈서베이', 'ISMS-P-KISA-2023-027'), ('하나증권', 'ISMS-P-FSI-2023-005'), ('주식회사 하이퍼라운지', 'ISMS-P-KISA-2023-026'), ('하나은행', 'ISMS-P-FSI-2023-004'), ('주식회사 에스씨케이컴퍼니', 'ISMS-P-KISA-2023-025'), ('원스토어 주식회사', 'ISMS-P-KISA-2023-024'), ('씨제이제일제당(주)', 'ISMS-P-KISA-2023-023'), ('(주)GC케어', 'ISMS-P-KISA-2023-022'), ('예스이십사 주식회사', 'ISMS-P-KISA-2023-021'), ('한국고용정보원', 'ISMS-P-KISA-2023-020'), ('(주) 신한디에스', 'ISMS-P-KISA-2023-019')]

# %%
# TODO: JOIN 쿼리 작성 (여러 테이블을 사용하는 경우)
# 예시: 두 테이블을 조인하여 데이터 조회

join_query = """
-- TODO: JOIN 쿼리를 작성하세요
-- 예시:
-- SELECT a.column1, b.column2
-- FROM table1 a
-- INNER JOIN table2 b ON a.id = b.foreign_id
-- LIMIT 10;
"""

print("실행 쿼리:")
print(join_query)
print("\n결과:")

try:
    result = db.run(join_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# -- TODO: JOIN 쿼리를 작성하세요
# -- 예시:
# -- SELECT a.column1, b.column2
# -- FROM table1 a
# -- INNER JOIN table2 b ON a.id = b.foreign_id
# -- LIMIT 10;
#
#
# 결과:
# 쿼리 실행 오류: (psycopg2.ProgrammingError) can't execute an empty query
# [SQL:
# -- TODO: JOIN 쿼리를 작성하세요
# -- 예시:
# -- SELECT a.column1, b.column2
# -- FROM table1 a
# -- INNER JOIN table2 b ON a.id = b.foreign_id
# -- LIMIT 10;
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# TODO: 집계(Aggregation) 쿼리 작성
# 예시: GROUP BY, COUNT, SUM, AVG 등 사용

aggregation_query = """
-- TODO: 집계 쿼리를 작성하세요
-- 예시:
-- SELECT category, COUNT(*) as count, AVG(price) as avg_price
-- FROM products
-- GROUP BY category
-- ORDER BY count DESC;
"""

print("실행 쿼리:")
print(aggregation_query)
print("\n결과:")

try:
    result = db.run(aggregation_query)
    print(result)
except Exception as e:
    print(f"쿼리 실행 오류: {e}")
# Out:
# 실행 쿼리:
#
# -- TODO: 집계 쿼리를 작성하세요
# -- 예시:
# -- SELECT category, COUNT(*) as count, AVG(price) as avg_price
# -- FROM products
# -- GROUP BY category
# -- ORDER BY count DESC;
#
#
# 결과:
# 쿼리 실행 오류: (psycopg2.ProgrammingError) can't execute an empty query
# [SQL:
# -- TODO: 집계 쿼리를 작성하세요
# -- 예시:
# -- SELECT category, COUNT(*) as count, AVG(price) as avg_price
# -- FROM products
# -- GROUP BY category
# -- ORDER BY count DESC;
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## 7. Text2SQL 함수 구현
#
# **TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요**

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model("gpt-5.4-mini")

def text_to_sql(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문을 SQL로 변환
    """
    # TODO: 시스템 프롬프트를 팀 데이터에 맞게 수정하세요
    system_prompt = f"""
    당신은 SQL 전문가입니다.
    사용자의 질문을 SQL 쿼리로 변환하세요.

    데이터베이스 스키마:
    {db.table_info}

    규칙:
    - PostgreSQL 문법 사용
    - SELECT 쿼리만 생성 (INSERT, UPDATE, DELETE 금지)
    - SQL 코드만 반환 (설명 불필요)
    - 코드 블록(```) 없이 순수 SQL만 반환
    - 세미콜론(;)으로 끝내기

    사용 가능한 SQL 문법:
    - JOIN (INNER, LEFT, RIGHT, FULL)
    - GROUP BY, HAVING
    - 집계 함수 (COUNT, SUM, AVG, MIN, MAX)
    - 서브쿼리
    - WHERE, ORDER BY, LIMIT
    - CTE (WITH 절)
    - 윈도우 함수
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=question)
    ]

    response = llm.invoke(messages)
    sql = response.content.strip()

    # 코드 블록 제거
    if sql.startswith("```"):
        lines = sql.split("\n")
        sql = "\n".join(lines[1:-1]) if len(lines) > 2 else sql
        sql = sql.replace("sql", "").replace("```", "").strip()

    return sql

print("✓ Text2SQL 함수 준비 완료")
# Out:
# ✓ Text2SQL 함수 준비 완료

# %% [markdown]
# ## 8. Text2SQL 테스트
#
# **TODO: 팀 데이터에 맞는 자연어 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "인증구분이 ISMS-P 기업중에 유효기간이 2026년 12월 까지인 기업만 기업명과 인증번호를 알려줘."

print(f"질문: {question}\n")
print("="*80)

# SQL 생성
sql = text_to_sql(question, db)
print(f"\n생성된 SQL:")
print(sql)
print()

# SQL 실행
print("="*80)
print("\n실행 결과:")
try:
    result = db.run(sql)
    print(result)
except Exception as e:
    print(f"실행 오류: {e}")
# Out:
# 질문: 인증구분이 ISMS-P 기업중에 유효기간이 2026년 12월 까지인 기업만 기업명과 인증번호를 알려줘.
#
# ================================================================================
#
# 생성된 SQL:
# SELECT "기업명", "인증번호"
# FROM ismsp_certification_status
# WHERE "인증구분" = 'ISMS-P'
#   AND "유효기간" LIKE '2026-12%';
#
# ================================================================================
#
# 실행 결과:

# %% [markdown]
# ## 9. 완전한 Text2SQL 시스템 (SQL 실행 + 자연어 답변)
#
# **TODO: 답변 생성 프롬프트를 팀 데이터에 맞게 수정하세요**

# %%
def query_database(question: str, db: SQLDatabase) -> str:
    """
    자연어 질문 → SQL 생성 → 실행 → 자연어 답변
    """
    # 1. SQL 생성
    print(f"[1] SQL 생성 중...")
    sql = text_to_sql(question, db)
    print(f"    {sql}\n")

    # 2. SQL 실행
    print(f"[2] SQL 실행 중...")
    try:
        result = db.run(sql)
        print(f"    실행 완료\n")
    except Exception as e:
        return f"SQL 실행 오류: {e}"

    # 3. 자연어 답변 생성
    print(f"[3] 답변 생성 중...")

    # TODO: 시스템 프롬프트를 팀 데이터 도메인에 맞게 수정하세요
    system_prompt = """
    당신은 정보보안 컴플라이언서로 SQL 데이터 분석 전문가입니다.
    SQL 쿼리 결과를 기반으로 사용자의 질문에 자연스럽게 답변하세요.
    답변은 명확하고 이해하기 쉽게 작성하세요.
    """

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=f"""
        질문: {question}

        실행한 SQL:
        {sql}

        쿼리 결과:
        {result}

        위 결과를 바탕으로 질문에 답변해주세요.
        """)
    ]

    response = llm.invoke(messages)
    return response.content

print("✓ 완전한 Text2SQL 시스템 준비 완료")
# Out:
# ✓ 완전한 Text2SQL 시스템 준비 완료

# %%
from IPython.display import Markdown, display

# TODO: 팀 데이터에 맞는 질문을 작성하세요
question = "기업중에 대학교만을 알려줘"

print(f"질문: {question}\n")
print("="*80 + "\n")

answer = query_database(question, db)

print("\n" + "="*80)
print("\n답변:")
display(Markdown(answer))
# Out:
# 질문: 기업중에 대학교만을 알려줘
#
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "기업명"
# FROM ismsp_certification_status
# WHERE "기업명" LIKE '%대학교%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# ================================================================================
#
# 답변:
# 쿼리 결과에서 **대학교만** 보면 아래와 같습니다.
#
# - 사이버한국외국어대학교
# - 건국대학교
# - 순천향대학교
# - 세종대학교
# - 경희사이버대학교
# - 서울디지털대학교
# - 한국복지사이버대학교
# - 인하대학교
# - 서울사이버대학교
# - 동의대학교
# - 울산대학교
# - 성균관대학교
# - 명지대학교
# - 이화여자대학교
# - 한양대학교
# - 경희대학교
# - 국립대학법인서울대학교
# - 대구대학교
# - 상명대학교
# - 중앙대학교
# - 건양사이버대학교
# - 숭실사이버대학교
# - 동아대학교
# - 동국대학교
# - 조선대학교
# - 한국열린사이버대학교
# - 백석대학교
# - 호서대학교
# - 한국기술교육대학교
# - 연세대학교
# - 세종사이버대학교
# - 원광디지털대학교
# - 전남대학교
# - 숭실대학교
# - 영남대학교
# - 가천대학교
# - 원광대학교
# - 홍익대학교
# - 한국외국어대학교
# - 단국대학교
# - 고려대학교
# - 국민대학교
# - 한양사이버대학교
# - 국제사이버대학교
# - 대구사이버대학교
#
# 원하시면 제가 여기서 **병원/의료원 같은 기관은 제외하고 “순수 대학”만 다시 정리**해드릴게요.

# %% [markdown]
# ## 10. 다양한 질문으로 테스트
#
# **TODO: 최소 5개 이상의 다양한 질문으로 테스트하세요**

# %%
# TODO: 팀 데이터에 맞는 다양한 질문들을 작성하세요
# 기본 조회, JOIN, 집계, 정렬 등 다양한 유형의 질문 포함

questions = [
    "기업중에 대학교만을 알려줘",
    "기업중에 금융권인 기업만 골라서 알려줘",
    "인증구분중에 ISMS-P인 기업과 ISMS를 구분해서 알려줘",
    "인증의 범위중에서 쇼핑과 관련된 기업중에서 유효기간이 가장 많이 남은 기업 5개만 알려줘.",
    "인증번호에서 KISA가 들어간 인증번호와 다른 문자가 섞여있는데, 이를 구분해주고 왜 인증번호가 다른지 설명해줘."
]

for q in questions:
    print(f"\n{'='*80}")
    print(f"질문: {q}")
    print("="*80 + "\n")

    try:
        answer = query_database(q, db)
        print("\n답변:")
        display(Markdown(answer))
    except Exception as e:
        print(f"오류: {e}")
# Out:
# ================================================================================
# 질문: 기업중에 대학교만을 알려줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "기업명"
# FROM ismsp_certification_status
# WHERE "기업명" LIKE '%대학교%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 쿼리 결과 중 **대학 이름만** 추리면 아래와 같습니다.
#
# - 사이버한국외국어대학교
# - 건국대학교
# - 순천향대학교
# - 세종대학교
# - 경희사이버대학교
# - 서울디지털대학교
# - 한국복지사이버대학교
# - 인하대학교
# - 서울사이버대학교
# - 동의대학교
# - 울산대학교
# - 성균관대학교
# - 명지대학교
# - 이화여자대학교
# - 한양대학교
# - 경희대학교
# - 국립대학법인서울대학교
# - 대구대학교
# - 상명대학교
# - 중앙대학교
# - 건양사이버대학교
# - 숭실사이버대학교
# - 동아대학교
# - 동국대학교
# - 조선대학교
# - 한국열린사이버대학교
# - 백석대학교
# - 호서대학교
# - 한국기술교육대학교
# - 연세대학교
# - 제주대학교
# - 고신대학교
# - 세종사이버대학교
# - 원광디지털대학교
# - 전남대학교
# - 숭실대학교
# - 영남대학교
# - 가천대학교
# - 원광대학교
# - 홍익대학교
# - 한국외국어대학교
# - 단국대학교
# - 고려대학교
# - 국민대학교
# - 한양사이버대학교
# - 국제사이버대학교
# - 대구사이버대학교
#
# 참고로, 결과에는 **병원/의료원/의과대학 부속병원**도 함께 포함되어 있어서 제외했습니다.
# 원하시면 제가 **중복 제거한 최종 대학 목록만** 다시 정리해드릴게요.
# ================================================================================
# 질문: 기업중에 금융권인 기업만 골라서 알려줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "인증구분", "인증번호", "기업명", "인증의 범위", "유효기간"
# FROM ismsp_certification_status
# WHERE "인증의 범위" ILIKE '%금융%'
#    OR "기업명" ILIKE '%금융%';
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 네, 쿼리 결과 기준으로 **금융권 기업**만 추려보면 아래와 같습니다.
#
# ### 금융권 기업 목록
# - 주식회사 하이퍼리즘
# - KB국민카드
# - 엔에이치투자증권
# - 새마을금고중앙회
# - 대신증권(주)
# - 신한은행
# - 한국증권금융
# - 현대해상화재보험(주)
# - (주)한국디지털자산수탁
# - 케이비손해보험
# - 한국결제네트웍스(유)
# - (사)한국금융연수원
# - 교보증권(주)
# - 해피블록 주식회사
# - (주)비바리퍼블리카
# - 코스콤
# - 비씨카드(주)
# - 한국투자증권
# - 주식회사 웨이브릿지
# - 케이뱅크
# - 서민금융진흥원
# - 한화생명금융서비스(주)
# - 한국전자금융(주)
# - KB금융지주
# - 주식회사 더즌
# - 케이비증권
# - 쿠콘
# - 나이스정보통신(주)
# - 롯데손해보험주식회사
# - 지머니트랜스 주식회사
# - 헥토파이낸셜
# - 신한카드
# - 농협생명보험 주식회사
# - 삼성증권 주식회사
# - 엔에이치엔페이코 주식회사
# - (주)연합인포맥스
# - 롯데캐피탈(주)
# - 엔에이치엔두레이 주식회사
# - (주)엘지씨엔에스
# - 카카오뱅크
# - 우리금융캐피탈 주식회사
# - 금융결제원
# - 디비금융투자
# - 토스증권 주식회사
# - 주식회사 카카오페이증권
# - 하나증권
# - 주식회사 비엔케이시스템
# - 한화투자증권
# - 쿠팡페이 주식회사
# - 주식회사 페이게이트
# - 엔에이치농협캐피탈
# - (주)하나금융티아이
# - (주)더존비즈온
# - 효성에프엠에스(주)
# - 미래에셋증권
# - 신한투자증권(주)
#
# 원하시면 제가 다음 단계로
# **1) 은행 / 증권 / 카드 / 보험 / 캐피탈 / 핀테크로 분류해서 정리**하거나,
# **2) 현재 유효한 기업만 따로 추려서** 보여드릴게요.
# ================================================================================
# 질문: 인증구분중에 ISMS-P인 기업과 ISMS를 구분해서 알려줘
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "인증구분", COUNT(*) AS 기업수
# FROM ismsp_certification_status
# WHERE "인증구분" IN ('ISMS', 'ISMS-P')
# GROUP BY "인증구분"
# ORDER BY "인증구분";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 인증구분 기준으로 보면,
#
# - **ISMS 인증 기업**: **955개**
# - **ISMS-P 인증 기업**: **319개**
#
# 즉, **ISMS 인증 기업이 ISMS-P 인증 기업보다 636개 더 많습니다.**
#
# 원하시면 제가 이 결과를 **비율(%)**로도 계산해서 함께 정리해드릴게요.
# ================================================================================
# 질문: 인증의 범위중에서 쇼핑과 관련된 기업중에서 유효기간이 가장 많이 남은 기업 5개만 알려줘.
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT "기업명", "인증의 범위", "유효기간"
# FROM (
#     SELECT
#         "기업명",
#         "인증의 범위",
#         "유효기간",
#         SPLIT_PART("유효기간", '~', 2)::date AS expiry_date,
#         ROW_NUMBER() OVER (ORDER BY SPLIT_PART("유효기간", '~', 2)::date DESC) AS rn
#     FROM ismsp_certification_status
#     WHERE "인증의 범위" LIKE '%쇼핑%'
# ) t
# WHERE rn <= 5
# ORDER BY expiry_date DESC;
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 쇼핑 관련 인증의 범위 중에서 **유효기간이 가장 많이 남은 기업 5개**는 아래와 같습니다.
#
# 1. **(주)티디에이치컴퍼니**
#    - 인증의 범위: 온라인 쇼핑몰 운영(오까네)(정보통신망법 제47조의7에 따른 인증의 특례)
#    - 유효기간: **2026-04-15 ~ 2029-04-14**
#
# 2. **(주)아성다이소**
#    - 인증의 범위: 온라인 쇼핑몰 운영(다이소몰)
#    - 유효기간: **2026-04-15 ~ 2029-04-14**
#
# 3. **(주)샵링커지앤씨**
#    - 인증의 범위: 샵링커 쇼핑몰통합관리 솔루션
#    - 유효기간: **2026-04-15 ~ 2029-04-14**
#
# 4. **주식회사 케이티알파**
#    - 인증의 범위: 대표홈페이지 외 kt알파 쇼핑, 기프티쇼 대국민서비스
#    - 유효기간: **2026-04-01 ~ 2029-03-31**
#
# 5. **셀린느코리아(유)**
#    - 인증의 범위: 온라인쇼핑몰 서비스 운영(셀린느닷컴)
#    - 유효기간: **2026-04-01 ~ 2029-03-31**
#
# 참고로, 상위 3개 기업은 모두 **2029-04-14**까지로 가장 길게 남아 있습니다.
# ================================================================================
# 질문: 인증번호에서 KISA가 들어간 인증번호와 다른 문자가 섞여있는데, 이를 구분해주고 왜 인증번호가 다른지 설명해줘.
# ================================================================================
#
# [1] SQL 생성 중...
#     SELECT
#   "인증번호",
#   CASE
#     WHEN "인증번호" LIKE '%KISA%' THEN 'KISA 포함'
#     ELSE 'KISA 미포함'
#   END AS "KISA_구분",
#   CASE
#     WHEN "인증번호" LIKE 'ISMS-P-KISA-%' THEN 'ISMS-P'
#     WHEN "인증번호" LIKE 'ISMS-KISA-%' THEN 'ISMS'
#     ELSE '기타'
#   END AS "인증구분_추정",
#   "기업명",
#   "인증의 범위",
#   "유효기간"
# FROM ismsp_certification_status
# ORDER BY "인증번호";
#
# [2] SQL 실행 중...
#     실행 완료
#
# [3] 답변 생성 중...
#
# 답변:
# 조회 결과를 보면 **인증번호는 모두 KISA 포함 여부와 관계없이 여러 형식이 섞여** 있습니다.
# 즉, “KISA가 들어간 인증번호”와 “다른 문자가 섞인 인증번호”는 단순히 **발급 유형/대상에 따라 번호 체계가 다르기 때문**입니다.
#
# ## 1) KISA 포함 여부로 구분
# SQL 기준으로는 아래처럼 나뉩니다.
#
# - **KISA 포함**: 인증번호에 `KISA` 문자열이 포함된 경우
#   예: `ISMS-KISA-2019-002`, `ISMS-P-KISA-2024-001`
# - **KISA 미포함**: 인증번호에 `KISA`가 없는 경우
#   예: `ISMS-FSI-2019-004`, `ISMS-P-FSI-2020-001`
#
# ## 2) 인증번호 형태별 추정 구분
# 쿼리 결과를 보면 인증번호는 크게 아래 패턴으로 보입니다.
#
# - **`ISMS-KISA-...`**
#   - 일반 ISMS 인증으로 보이는 유형
#   - 예: 대학, 병원, 플랫폼, 쇼핑몰 등 다양한 기관
# - **`ISMS-P-KISA-...`**
#   - ISMS-P 인증으로 보이는 유형
#   - 예: 개인정보 처리 범위가 큰 서비스, 온라인 서비스, 금융/플랫폼 등
# - **`ISMS-FSI-...`**
#   - 금융권 특화 인증 계열로 보이는 유형
#   - `KISA`는 없지만 금융서비스 대상 인증번호로 보임
# - **`ISMS-P-FSI-...`**
#   - ISMS-P와 금융권(FSI) 특성이 결합된 별도 체계로 보임
#   - 즉, 개인정보보호 중심의 ISMS-P 성격이 있으면서 금융권 특수 기준이 반영된 번호 체계로 해석 가능
#
# ## 3) 왜 인증번호가 다른가?
# 인증번호가 다른 이유는 보통 다음과 같습니다.
#
# 1. **인증 제도 자체가 다름**
#    - `ISMS`, `ISMS-P`, `FSI`는 적용 대상과 심사 기준이 다릅니다.
#    - 그래서 번호 앞부분도 다르게 부여됩니다.
#
# 2. **대상 기관의 업종/서비스가 다름**
#    - 금융기관, 대학, 병원, 쇼핑몰, 플랫폼 등은 심사 기준과 관리 범위가 달라 별도 체계를 가질 수 있습니다.
#
# 3. **심사 기준의 특수성**
#    - `FSI`는 금융권 보안/통제 특성이 반영된 체계로 보이고,
#    - `ISMS-P`는 개인정보 보호 요구가 추가된 체계입니다.
#
# 4. **발급 연도와 순번 관리**
#    - 뒤의 숫자(`2019-004`, `2024-001` 등)는 보통 **연도 + 순번** 형태라서, 같은 유형이라도 발급 시점에 따라 달라집니다.
#
# ## 4) 현재 데이터에서 보이는 핵심 정리
# - **KISA 포함**: `ISMS-KISA-*`, `ISMS-P-KISA-*`
# - **KISA 미포함**: `ISMS-FSI-*`, `ISMS-P-FSI-*`
# - 따라서 `KISA` 유무는 **인증 주체/체계 구분용 식별자**로 보는 것이 맞습니다.
# - “다른 문자가 섞여 있다”는 것은 **오류라기보다 인증 체계가 여러 갈래로 나뉘어 있기 때문**입니다.
#
# 원하시면 제가 이 결과를 기준으로
# **인증번호 패턴별 건수 요약**이나 **KISA 포함/미포함 기관 목록만 따로 정리**해드릴게요.

# %% [markdown]
# ## 프로젝트 점검 체크리스트
#
# **완료한 항목을 확인하세요:**
#
# - [ ] CSV 파일 준비 및 데이터 확인 완료
# - [ ] CSV 데이터 탐색 및 통계 분석 완료
# - [ ] Supabase 연결 완료
# - [ ] CSV 데이터 업로드 완료
# - [ ] 직접 작성한 SQL 쿼리 테스트 완료 (최소 3개)
# - [ ] Text2SQL 함수 구현 및 프롬프트 수정 완료
# - [ ] 자연어 질문으로 SQL 생성 테스트 완료
# - [ ] 완전한 Text2SQL 시스템 (답변 생성) 테스트 완료
# - [ ] 최소 5개 이상의 다양한 질문으로 테스트 완료
#
# ---
#
# ## 추가 개선 아이디어
#
# 1. **프롬프트 개선**: SQL 생성 정확도 향상을 위한 예시 추가
# 2. **에러 핸들링**: SQL 오류 발생 시 재시도 로직 구현
# 3. **쿼리 검증**: 생성된 SQL이 안전한지 검증하는 로직 추가
# 4. **결과 포맷팅**: 테이블 형태로 결과 출력
# 5. **쿼리 히스토리**: 실행한 쿼리와 결과를 저장하여 재사용
# 6. **고급 SQL**: 서브쿼리, CTE, 윈도우 함수 활용
